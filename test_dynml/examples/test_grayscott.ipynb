# %% [markdown]
# # test_grayscott.ipynb

# %% [markdown]
# ### Install

# %%
pip install git+https://github.com/grmacchio/dynml.git

# %% [markdown]
# ### Imports and Configuration

# %%
from math import floor

from matplotlib.pyplot import subplots, show
from torch import arange, linspace, pi
from torch.linalg import norm
from numpy import round

from dynml.dyn.cont.ode.firstorder.discretize import gen_approx_discrete_sys
from dynml.examples.grayscott import GrayScott
from dynml.dyn.discrete.numsolve import gen_num_trajs
from dynml.utils.config import config

# %%
config(64, 0)
# Out:
# 'cpu'

# %% [markdown]
# ### Examine Trajectories with Stable Fixed Point

# %%
first_order_sys = GrayScott()                                                         # semi-linear first order system

print(first_order_sys.A.shape)

dt = 0.01                                                                       # set the time step
discretization_method = 'rk3cn'                                                 # set the discretization method
implicit_solver = 'diag'                                                        # set the implicit solver
discrete_sys = gen_approx_discrete_sys(first_order_sys, dt,                     # generate the discrete system
                                       discretization_method, implicit_solver)

num_traj_sqrt = 2                                                               # set the square root of the number of trajectories for plotting
num_traj = num_traj_sqrt**2                                                     # set the number of trajectories
t_final = 100.0                                                                 # set the final time
num_samples = floor(t_final/dt) + 1                                             # set the number of samples
trajs = gen_num_trajs(discrete_sys, first_order_sys.gen_ic, num_traj,           # generate the trajectories
                      num_samples, compute='cpu', output='cpu', pbar=True)
# Out:
# torch.Size([260, 260])
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[3], line 8
#       6 discretization_method = 'rk3cn'                                                 # set the discretization method
#       7 implicit_solver = 'diag'                                                        # set the implicit solver
# ----> 8 discrete_sys = gen_approx_discrete_sys(first_order_sys, dt,                     # generate the discrete system
#       9                                        discretization_method, implicit_solver)
#      11 num_traj_sqrt = 2                                                               # set the square root of the number of trajectories for plotting
#      12 num_traj = num_traj_sqrt**2                                                     # set the number of trajectories
#
# File ~/anaconda3/lib/python3.10/site-packages/dynml/dyn/cont/ode/firstorder/discretize.py:1450, in gen_approx_discrete_sys(sys, dt, method, implicit_solver)
#    1447         raise ValueError("Semi-linear time-stepping methods require a "
#    1448                          + "semi-linear implicit solver")
#    1449     # return the approximate discrete system
# -> 1450     method_inst_semi = method_cls_semi(dt, sys, implicit_solver)
#    1451     return DiscretizedFirstOrderSystem(method_inst_semi)
#    1452 except NotImplementedError:
#    1453     # see if the desired time-stepping method is explicit
#
# File ~/anaconda3/lib/python3.10/site-packages/dynml/dyn/cont/ode/firstorder/discretize.py:1325, in RK3CN.__init__(self, dt, sys, implicit_solver)
#    1305 """Initialize the superclass.
#    1306
#    1307 This method initializes the superclass ``SemiLinearTimeStepMethod``.
#    (...)
#    1322 |   None
#    1323 """
#    1324 # initialize the superclass
# -> 1325 super().__init__(dt, sys, implicit_solver)
#
# File ~/anaconda3/lib/python3.10/site-packages/dynml/dyn/cont/ode/firstorder/discretize.py:1068, in SemiLinearTimeStepMethod.__init__(self, dt, sys, implicit_solver)
#    1066 self.dt = dt
#    1067 self.sys = sys
# -> 1068 self.init_implicit_solvers(LinearSolver.lookup(implicit_solver))
#    1069 if norm(self.sys.A - diag(diag(self.sys.A)), ord='fro') == 0.0:
#    1070     self._diag_A = diag(sys.A)
#
# File ~/anaconda3/lib/python3.10/site-packages/dynml/dyn/cont/ode/firstorder/discretize.py:1263, in RK3CN.init_implicit_solvers(self, implicit_solver_cls)
#    1241 """Initialize the implicit solvers.
#    1242
#    1243 This method initializes the implicit solvers. In particular, this
#    (...)
#    1260         Flow. Vol. 148. New York: Springer, 2002. p. 149.
#    1261 """
#    1262 Bp = [1.0 / 6, 5.0 / 24, 1.0 / 8]
# -> 1263 Ms = [eye(self.sys.dims_state[-1], device=self.sys.A.device)
#    1264       - b * self.dt * self.sys.A for b in Bp]
#    1265 implicit_solver_insts = [implicit_solver_cls(M) for M in Ms]
#    1266 self.implicit_solver_insts = ModuleList(implicit_solver_insts)
#
# File ~/anaconda3/lib/python3.10/site-packages/dynml/dyn/cont/ode/firstorder/discretize.py:1263, in <listcomp>(.0)
#    1241 """Initialize the implicit solvers.
#    1242
#    1243 This method initializes the implicit solvers. In particular, this
#    (...)
#    1260         Flow. Vol. 148. New York: Springer, 2002. p. 149.
#    1261 """
#    1262 Bp = [1.0 / 6, 5.0 / 24, 1.0 / 8]
# -> 1263 Ms = [eye(self.sys.dims_state[-1], device=self.sys.A.device)
#    1264       - b * self.dt * self.sys.A for b in Bp]
#    1265 implicit_solver_insts = [implicit_solver_cls(M) for M in Ms]
#    1266 self.implicit_solver_insts = ModuleList(implicit_solver_insts)
#
# RuntimeError: The size of tensor a (130) must match the size of tensor b (260) at non-singleton dimension 1

# %%
norms = norm(trajs, dim=-1)                                                     # compute the norms of the trajectories

# %%
num_traj_plot = num_traj                                                        # set the number of trajectories to plot
t = linspace(0, t_final, num_samples)                                           # generate the time vector
fig, ax = subplots()                                                            # generate the figure and axis
for i in range(num_traj):                                                       # loop over the trajectories
    ax.plot(t, norms[i], label=f'{i + 1}')                                      # plot the norms
ax.set_xlabel('$t$')                                                            # set the x-axis label
ax.set_ylabel('$\\|x\\|_2$')                                                    # set the y-axis label
ax.legend()                                                                     # add the legend
ax.grid()                                                                       # add the grid
show()                                                                          # show the plot
